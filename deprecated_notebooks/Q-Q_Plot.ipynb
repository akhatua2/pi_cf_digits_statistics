# %%
from statsmodels.graphics.gofplots import qqplot
from matplotlib import pyplot as plt
plt.rcParams['figure.figsize'] = [10, 7]
plt.rc('font', size=14)
from scipy.stats import norm, uniform, chi2, chi
import numpy as np
np.random.seed(0)
import pickle

# %% [markdown]
# # Q-Q Plot of p_values for pairs of digits

# %%
with open("p_values.pickle", "rb") as input_file:
    p_val_arr = pickle.load(input_file)

# %%
x = np.array(p_val_arr) 
qq_plot = qqplot(x, uniform,fit=True,line="45")
plt.grid()
plt.legend(['p_value distribution', 'uniform distribution'])
plt.savefig("q-q_plot.png")
plt.show()
